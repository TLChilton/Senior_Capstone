# %% [markdown]
# Here's an example of using the code in dataDownload.py to download daily Google Trends data

# %%
import dataDownload as dd

df_tslaTrend = dd.get_daily_data(
    word="Tesla",
    start_year=2010,
    start_mon=6,
    start_day=30,
    stop_year=2021,
    stop_mon=3,
    stop_day=22
)

df_tslaTrend.head()
# Out:
# Tesla:2010-06-30 2010-06-30
# Tesla:2010-07-01 2010-07-31
# Tesla:2010-08-01 2010-08-31
# Tesla:2010-09-01 2010-09-30
# Tesla:2010-10-01 2010-10-31
# Tesla:2010-11-01 2010-11-30
# Tesla:2010-12-01 2010-12-31
# Tesla:2011-01-01 2011-01-31
# Tesla:2011-02-01 2011-02-28
# Tesla:2011-03-01 2011-03-31
# Tesla:2011-04-01 2011-04-30
# Tesla:2011-05-01 2011-05-31
# Tesla:2011-06-01 2011-06-30
# Tesla:2011-07-01 2011-07-31
# Tesla:2011-08-01 2011-08-31
# Tesla:2011-09-01 2011-09-30
# Tesla:2011-10-01 2011-10-31
# Tesla:2011-11-01 2011-11-30
# Tesla:2011-12-01 2011-12-31
# Tesla:2012-01-01 2012-01-31
# Tesla:2012-02-01 2012-02-29
# Tesla:2012-03-01 2012-03-31
# Tesla:2012-04-01 2012-04-30
# Tesla:2012-05-01 2012-05-31
# Tesla:2012-06-01 2012-06-30
# Tesla:2012-07-01 2012-07-31
# Tesla:2012-08-01 2012-08-31
# Tesla:2012-09-01 2012-09-30
# Tesla:2012-10-01 2012-10-31
# Tesla:2012-11-01 2012-11-30
# Tesla:2012-12-01 2012-12-31
# Tesla:2013-01-01 2013-01-31
# Tesla:2013-02-01 2013-02-28
# ...

# %%
df_tslaTrend.to_csv('Data/tslaTrend2.csv')
