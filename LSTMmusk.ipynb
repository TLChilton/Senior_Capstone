# %%
import pandas as pd
import numpy as np
#tf.compat.v1.disable_v2_behavior()
from math import sqrt, floor
from matplotlib import pyplot

# %% [markdown]
# ## Load Data

# %%
df_tweets = pd.read_csv("Data/musk_2021.csv", parse_dates = ['date'], index_col=0)
df_tweets.set_index("date", inplace=True)
df_tweets.sort_index(ascending=True, inplace=True)
print(df_tweets.shape)
df_tweets.head(1)
# Out:
# (12339, 37)
#                               id  conversation_id    created_at  timezone  \
# date
# 2010-06-04 18:31:57  15434727182      15434727182  1.275676e+12         0
#
#                      place                                              tweet  \
# date
# 2010-06-04 18:31:57    NaN  Please ignore prior tweets, as that was someon...
#
#                     language hashtags cashtags   user_id  ...  geo source  \
# date                                                      ...
# 2010-06-04 18:31:57       en       []       []  44196397  ...  NaN    NaN
#
#                     user_rt_id  user_rt  retweet_id reply_to retweet_date  \
# date
# 2010-06-04 18:31:57        NaN      NaN         NaN       []          NaN
#
#                     translate  trans_src trans_dest
# date
# 2010-06-04 18:31:57       NaN        NaN        NaN
#
# [1 rows x 37 columns]

# %%
df_trump = pd.read_csv("Data/trump_tweets.csv", parse_dates = ['date'], index_col=7)
print(df_trump.shape)
df_trump.head(1)
# Out:
# (56571, 8)
#                                id  \
# date
# 2009-05-04 18:54:00  1.698309e+09
#
#                                                                   text  \
# date
# 2009-05-04 18:54:00  Be sure to tune in and watch Donald Trump on L...
#
#                     isRetweet isDeleted              device  favorites  \
# date
# 2009-05-04 18:54:00         f         f  Twitter Web Client        939
#
#                      retweets isFlagged
# date
# 2009-05-04 18:54:00       519         f

# %%
df_doge = pd.read_csv("Data/Daily-DOGE-USD.csv", parse_dates=['Date'], index_col=0)
print(df_doge.shape)
df_doge.head(3)
# Out:
# (1462, 6)
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2017-08-24  0.001731  0.001845  0.001722  0.001816   0.001816  4796720.0
# 2017-08-25  0.001808  0.001830  0.001762  0.001790   0.001790  2654040.0
# 2017-08-26  0.001787  0.001797  0.001735  0.001778   0.001778  1935350.0

# %% [markdown]
# # LSTM Application

# %% [markdown]
# ## Function For Converting Time Series Data For Supervised Learning

# %%
# convert series to supervised learning
# developed in this blog post https://machinelearningmastery.com/convert-time-series-supervised-learning-problem-python/
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ..., t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
	# drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %% [markdown]
# ## Preparing Data

# %% [markdown]
# ### Trimming and merging dataframes

# %%
# Aligning Tweet Data with Doge Data
df_tweets = df_tweets.loc[(df_tweets.index >= '2017-08-24')]
df_tweets = df_tweets.loc[(df_tweets.index <= '2021-01-08')]
# Dropping columns that are unexpected to be useful
df_tweets = df_tweets.drop(columns=[
    'id', 'conversation_id', 'timezone', 'place',
    'language', 'user_id', 'geo', 'source', 'user_rt_id',
    'user_rt', 'retweet_id', 'reply_to', 'retweet_date',
    'translate', 'trans_src', 'trans_dest', 'user_id_str',
    'username', 'name', 'day', 'hour', 'link', 'urls',
    'photos', 'video', 'thumbnail', 'retweet', 'quote_url',
    'search', 'near', 'created_at', 'tweet', 'hashtags',
    'cashtags'
], axis=1)

# Changing by the second data to by the day data
changed1 = df_tweets.groupby([df_tweets.index.date]).size().reset_index(name='Musk Tweet Count')
changed2 = df_tweets.groupby([df_tweets.index.date]).agg('sum')
changed1 = changed1.set_index('index')

df_tweets = changed1.merge(changed2, how='outer', left_index=True, right_index=True)
df_tweets = df_tweets.rename_axis('Date')
df_tweets.rename(columns={"nlikes": "Musk Likes", "nreplies": "Musk Replies", "nretweets": "Musk Retweets"}, inplace=True)
print(df_tweets.shape)
df_tweets.head(1)
# Out:
# (1058, 4)
#             Musk Tweet Count  Musk Likes  Musk Replies  Musk Retweets
# Date
# 2017-08-25                12       59024          1790           6875

# %%
# Aligning Tweet Data with Doge Data
df_trump = df_trump.loc[(df_trump.index >= '2017-08-24')]
# Dropping ID column since it's unexpected to be useful
df_trump = df_trump.drop(columns=['id'], axis=1)

# Changing by the second data to by the day data
changed1 = df_trump.groupby([df_trump.index.date]).size().reset_index(name='Trump Tweet Count')
changed2 = df_trump.groupby([df_trump.index.date]).agg('sum')
changed1 = changed1.set_index('index')

df_trump = changed1.merge(changed2, how='outer', left_index=True, right_index=True)
df_trump = df_trump.rename_axis('Date')
df_trump.rename(columns={"favorites": "Trump Favorites", "retweets": "Trump Retweets"}, inplace=True)
print(df_trump.shape)
df_trump.head(1)
# Out:
# (1227, 3)
#             Trump Tweet Count  Trump Favorites  Trump Retweets
# Date
# 2017-08-24                 15           553551          146247

# %%
# Aligning Doge Data with Tweet Data
df_doge = df_doge.loc[(df_doge.index <= '2021-01-08')]
#df_doge = df_doge.drop(columns=['Open', 'High', 'Low', 'Close'], axis=1)
print(df_doge.shape)
df_doge.plot(y='Volume', figsize=(15,5)).set_title('DogeCoin Daily Volume')
# Out:
# (1234, 6)
# Text(0.5, 1.0, 'DogeCoin Daily Volume')

# %%
# Merging Two Data Sets Together
df = df_doge.merge(df_tweets, how='outer', left_index=True, right_index=True)
df = df.merge(df_trump, how='outer', left_index=True, right_index=True)
df.fillna(0, inplace=True)
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2017-08-24  0.001731  0.001845  0.001722  0.001816   0.001816  4796720.0
# 2017-08-25  0.001808  0.001830  0.001762  0.001790   0.001790  2654040.0
# 2017-08-26  0.001787  0.001797  0.001735  0.001778   0.001778  1935350.0
# 2017-08-27  0.001779  0.001784  0.001745  0.001760   0.001760  2241620.0
# 2017-08-28  0.001764  0.001825  0.001751  0.001825   0.001825  3210440.0
#
#             Musk Tweet Count  Musk Likes  Musk Replies  Musk Retweets  \
# Date
# 2017-08-24               0.0         0.0           0.0            0.0
# 2017-08-25              12.0     59024.0        1790.0         6875.0
# 2017-08-26               2.0      2092.0          96.0          127.0
# 2017-08-27              11.0     33508.0        1190.0         6658.0
# 2017-08-28              18.0    211029.0        6746.0        52456.0
#
#             Trump Tweet Count  Trump Favorites  Trump Retweets
# Date
# 2017-08-24               15.0         553551.0        146247.0
# 2017-08-25               14.0         676700.0        148426.0
# 2017-08-26               12.0         577719.0        130227.0
# 2017-08-27               11.0         733628.0        144351.0
# 2017-08-28                4.0              0.0         68447.0

# %% [markdown]
# ### Converting Data for Supervised Learning

# %%
from sklearn.preprocessing import MinMaxScaler

values = df.values
# integer encoding of labels (not using yet here)
#encoder = LabelEncoder()
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0,1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)

# Drop Columns of Variables We Aren't Predicting
reframed.drop(reframed.columns[[13,14,15,16,17,19,20,21,22,23,24,25]], axis=1, inplace=True)
#reframed.drop(reframed.columns[[9,11,12,13,14,15,16,17]], axis=1, inplace=True)
print(reframed.shape)
reframed.head()
# Out:
# (1233, 14)
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.101139   0.098279   0.118131   0.106273   0.106273   0.001402
# 2   0.105638   0.097480   0.120875   0.104752   0.104752   0.000776
# 3   0.104411   0.095723   0.119023   0.104050   0.104050   0.000566
# 4   0.103944   0.095030   0.119709   0.102996   0.102996   0.000655
# 5   0.103067   0.097214   0.120121   0.106800   0.106800   0.000938
#
#    var7(t-1)  var8(t-1)  var9(t-1)  var10(t-1)  var11(t-1)  var12(t-1)  \
# 1   0.000000   0.000000   0.000000    0.000000    0.098039    0.067624
# 2   0.214286   0.025345   0.019659    0.018324    0.091503    0.082669
# 3   0.035714   0.000898   0.001054    0.000339    0.078431    0.070577
# 4   0.196429   0.014389   0.013069    0.017746    0.071895    0.089623
# 5   0.321429   0.090617   0.074088    0.139814    0.026144    0.000000
#
#    var13(t-1)   var6(t)
# 1    0.058361  0.000776
# 2    0.059230  0.000566
# 3    0.051968  0.000655
# 4    0.057604  0.000938
# 5    0.027314  0.002011

# %% [markdown]
# ## Running Model

# %%
# split into train, test, and prediction sets
values = reframed.values
#n_predict = floor((len(values) * 0.10))
n_predict = floor(365/4)
n_train = floor((len(values) * 0.80))
train = values[:n_train, :]
test = values[n_train:len(values)-n_predict, :]
predict = values[len(values)-n_predict:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
predict_X, predict_y = predict[:, :-1], predict[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
predict_X = predict_X.reshape((predict_X.shape[0], 1, predict_X.shape[1]))

print(train_X.shape, train_y.shape, test_X.shape, test_y.shape, predict_X.shape, predict_y.shape)
# Out:
# (986, 1, 13) (986,) (156, 1, 13) (156,) (91, 1, 13) (91,)

# %%
# design network
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, TimeDistributed, Activation
from tensorflow.keras.metrics import RootMeanSquaredError

model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2]), dropout=0.2, return_sequences=True))
model.add(LSTM(100, dropout=0.2, return_sequences=False))
model.add(Dense(1, activation='linear'))

model.compile(
    loss='mae',
    optimizer='adam',
    metrics=[RootMeanSquaredError()])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 1, 50)             12800
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               60400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 73,301
# Trainable params: 73,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit network
history = model.fit(train_X, train_y, epochs=150, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.figure(figsize=(15,5))
pyplot.subplot(1, 2, 1)
pyplot.plot(history.history['loss'], label='train_MAE')
pyplot.plot(history.history['val_loss'], label='test_MAE')
pyplot.legend()
pyplot.subplot(1, 2, 2)
pyplot.plot(history.history['root_mean_squared_error'], label='train_RMSE')
pyplot.plot(history.history['val_root_mean_squared_error'], label='test_RMSE')
pyplot.legend()
pyplot.show()
# Out:
# Epoch 1/150
# 14/14 - 3s - loss: 0.0084 - root_mean_squared_error: 0.0133 - val_loss: 0.0214 - val_root_mean_squared_error: 0.0361
# Epoch 2/150
# 14/14 - 0s - loss: 0.0205 - root_mean_squared_error: 0.0234 - val_loss: 0.0272 - val_root_mean_squared_error: 0.0435
# Epoch 3/150
# 14/14 - 0s - loss: 0.0091 - root_mean_squared_error: 0.0154 - val_loss: 0.0230 - val_root_mean_squared_error: 0.0397
# Epoch 4/150
# 14/14 - 0s - loss: 0.0131 - root_mean_squared_error: 0.0172 - val_loss: 0.0273 - val_root_mean_squared_error: 0.0436
# Epoch 5/150
# 14/14 - 0s - loss: 0.0089 - root_mean_squared_error: 0.0151 - val_loss: 0.0232 - val_root_mean_squared_error: 0.0398
# Epoch 6/150
# 14/14 - 0s - loss: 0.0117 - root_mean_squared_error: 0.0164 - val_loss: 0.0264 - val_root_mean_squared_error: 0.0428
# Epoch 7/150
# 14/14 - 0s - loss: 0.0088 - root_mean_squared_error: 0.0149 - val_loss: 0.0234 - val_root_mean_squared_error: 0.0400
# Epoch 8/150
# 14/14 - 0s - loss: 0.0105 - root_mean_squared_error: 0.0158 - val_loss: 0.0251 - val_root_mean_squared_error: 0.0415
# Epoch 9/150
# 14/14 - 0s - loss: 0.0091 - root_mean_squared_error: 0.0149 - val_loss: 0.0234 - val_root_mean_squared_error: 0.0400
# Epoch 10/150
# 14/14 - 0s - loss: 0.0096 - root_mean_squared_error: 0.0150 - val_loss: 0.0235 - val_root_mean_squared_error: 0.0400
# Epoch 11/150
# 14/14 - 0s - loss: 0.0094 - root_mean_squared_error: 0.0151 - val_loss: 0.0232 - val_root_mean_squared_error: 0.0397
# Epoch 12/150
# 14/14 - 0s - loss: 0.0093 - root_mean_squared_error: 0.0150 - val_loss: 0.0229 - val_root_mean_squared_error: 0.0393
# Epoch 13/150
# 14/14 - 0s - loss: 0.0093 - root_mean_squared_error: 0.0147 - val_loss: 0.0230 - val_root_mean_squared_error: 0.0394
# Epoch 14/150
# 14/14 - 0s - loss: 0.0094 - root_mean_squared_error: 0.0147 - val_loss: 0.0231 - val_root_mean_squared_error: 0.0394
# Epoch 15/150
# 14/14 - 0s - loss: 0.0090 - root_mean_squared_error: 0.0144 - val_loss: 0.0224 - val_root_mean_squared_error: 0.0386
# Epoch 16/150
# 14/14 - 0s - loss: 0.0094 - root_mean_squared_error: 0.0149 - val_loss: 0.0227 - val_root_mean_squared_error: 0.0390
# Epoch 17/150
# 14/14 - 0s - loss: 0.0092 - root_mean_squared_error: 0.0146 - val_loss: 0.0223 - val_root_mean_squared_error: 0.0385
# Epoch 18/150
# 14/14 - 0s - loss: 0.0090 - root_mean_squared_error: 0.0142 - val_loss: 0.0221 - val_root_mean_squared_error: 0.0382
# Epoch 19/150
# 14/14 - 0s - loss: 0.0091 - root_mean_squared_error: 0.0143 - val_loss: 0.0220 - val_root_mean_squared_error: 0.0381
# Epoch 20/150
# 14/14 - 0s - loss: 0.0091 - root_mean_squared_error: 0.0142 - val_loss: 0.0219 - val_root_mean_squared_error: 0.0380
# Epoch 21/150
# 14/14 - 0s - loss: 0.0090 - root_mean_squared_error: 0.0144 - val_loss: 0.0217 - val_root_mean_squared_error: 0.0376
# Epoch 22/150
# 14/14 - 0s - loss: 0.0090 - root_mean_squared_error: 0.0142 - val_loss: 0.0215 - val_root_mean_squared_error: 0.0374
# Epoch 23/150
# 14/14 - 0s - loss: 0.0088 - root_mean_squared_error: 0.0139 - val_loss: 0.0213 - val_root_mean_squared_error: 0.0372
# Epoch 24/150
# 14/14 - 0s - loss: 0.0088 - root_mean_squared_error: 0.0138 - val_loss: 0.0212 - val_root_mean_squared_error: 0.0371
# Epoch 25/150
# 14/14 - 0s - loss: 0.0088 - root_mean_squared_error: 0.0138 - val_loss: 0.0211 - val_root_mean_squared_error: 0.0370
# Epoch 26/150
# 14/14 - 0s - loss: 0.0088 - root_mean_squared_error: 0.0139 - val_loss: 0.0209 - val_root_mean_squared_error: 0.0367
# Epoch 27/150
# 14/14 - 0s - loss: 0.0086 - root_mean_squared_error: 0.0137 - val_loss: 0.0202 - val_root_mean_squared_error: 0.0360
# Epoch 28/150
# 14/14 - 0s - loss: 0.0084 - root_mean_squared_error: 0.0130 - val_loss: 0.0197 - val_root_mean_squared_error: 0.0355
# Epoch 29/150
# 14/14 - 0s - loss: 0.0088 - root_mean_squared_error: 0.0135 - val_loss: 0.0199 - val_root_mean_squared_error: 0.0357
# Epoch 30/150
# 14/14 - 0s - loss: 0.0088 - root_mean_squared_error: 0.0133 - val_loss: 0.0194 - val_root_mean_squared_error: 0.0351
# Epoch 31/150
# 14/14 - 0s - loss: 0.0082 - root_mean_squared_error: 0.0134 - val_loss: 0.0190 - val_root_mean_squared_error: 0.0347
# Epoch 32/150
# 14/14 - 0s - loss: 0.0080 - root_mean_squared_error: 0.0125 - val_loss: 0.0185 - val_root_mean_squared_error: 0.0341
# Epoch 33/150
# 14/14 - 0s - loss: 0.0085 - root_mean_squared_error: 0.0127 - val_loss: 0.0184 - val_root_mean_squared_error: 0.0341
# Epoch 34/150
# 14/14 - 0s - loss: 0.0083 - root_mean_squared_error: 0.0128 - val_loss: 0.0181 - val_root_mean_squared_error: 0.0337
# Epoch 35/150
# 14/14 - 0s - loss: 0.0080 - root_mean_squared_error: 0.0125 - val_loss: 0.0175 - val_root_mean_squared_error: 0.0331
# Epoch 36/150
# 14/14 - 0s - loss: 0.0077 - root_mean_squared_error: 0.0125 - val_loss: 0.0172 - val_root_mean_squared_error: 0.0330
# Epoch 37/150
# 14/14 - 0s - loss: 0.0081 - root_mean_squared_error: 0.0127 - val_loss: 0.0169 - val_root_mean_squared_error: 0.0327
# Epoch 38/150
# 14/14 - 0s - loss: 0.0074 - root_mean_squared_error: 0.0116 - val_loss: 0.0157 - val_root_mean_squared_error: 0.0316
# Epoch 39/150
# 14/14 - 0s - loss: 0.0078 - root_mean_squared_error: 0.0122 - val_loss: 0.0152 - val_root_mean_squared_error: 0.0312
# Epoch 40/150
# 14/14 - 0s - loss: 0.0078 - root_mean_squared_error: 0.0120 - val_loss: 0.0150 - val_root_mean_squared_error: 0.0310
# Epoch 41/150
# 14/14 - 0s - loss: 0.0076 - root_mean_squared_error: 0.0121 - val_loss: 0.0153 - val_root_mean_squared_error: 0.0310
# Epoch 42/150
# 14/14 - 0s - loss: 0.0075 - root_mean_squared_error: 0.0119 - val_loss: 0.0148 - val_root_mean_squared_error: 0.0305
# Epoch 43/150
# 14/14 - 0s - loss: 0.0071 - root_mean_squared_error: 0.0116 - val_loss: 0.0138 - val_root_mean_squared_error: 0.0297
# Epoch 44/150
# 14/14 - 0s - loss: 0.0065 - root_mean_squared_error: 0.0099 - val_loss: 0.0129 - val_root_mean_squared_error: 0.0290
# Epoch 45/150
# 14/14 - 0s - loss: 0.0074 - root_mean_squared_error: 0.0110 - val_loss: 0.0129 - val_root_mean_squared_error: 0.0292
# Epoch 46/150
# 14/14 - 0s - loss: 0.0075 - root_mean_squared_error: 0.0119 - val_loss: 0.0131 - val_root_mean_squared_error: 0.0295
# Epoch 47/150
# 14/14 - 0s - loss: 0.0080 - root_mean_squared_error: 0.0120 - val_loss: 0.0143 - val_root_mean_squared_error: 0.0301
# Epoch 48/150
# 14/14 - 0s - loss: 0.0074 - root_mean_squared_error: 0.0119 - val_loss: 0.0135 - val_root_mean_squared_error: 0.0297
# Epoch 49/150
# 14/14 - 0s - loss: 0.0067 - root_mean_squared_error: 0.0115 - val_loss: 0.0126 - val_root_mean_squared_error: 0.0291
# Epoch 50/150
# 14/14 - 0s - loss: 0.0063 - root_mean_squared_error: 0.0104 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0287
# Epoch 51/150
# 14/14 - 0s - loss: 0.0062 - root_mean_squared_error: 0.0107 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0285
# Epoch 52/150
# 14/14 - 0s - loss: 0.0058 - root_mean_squared_error: 0.0103 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0281
# Epoch 53/150
# 14/14 - 0s - loss: 0.0077 - root_mean_squared_error: 0.0114 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0284
# Epoch 54/150
# 14/14 - 0s - loss: 0.0081 - root_mean_squared_error: 0.0121 - val_loss: 0.0129 - val_root_mean_squared_error: 0.0293
# Epoch 55/150
# 14/14 - 0s - loss: 0.0077 - root_mean_squared_error: 0.0123 - val_loss: 0.0139 - val_root_mean_squared_error: 0.0299
# Epoch 56/150
# 14/14 - 0s - loss: 0.0071 - root_mean_squared_error: 0.0119 - val_loss: 0.0134 - val_root_mean_squared_error: 0.0296
# Epoch 57/150
# 14/14 - 0s - loss: 0.0059 - root_mean_squared_error: 0.0106 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0287
# Epoch 58/150
# 14/14 - 0s - loss: 0.0060 - root_mean_squared_error: 0.0101 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0283
# Epoch 59/150
# 14/14 - 0s - loss: 0.0069 - root_mean_squared_error: 0.0109 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0285
# Epoch 60/150
# 14/14 - 0s - loss: 0.0069 - root_mean_squared_error: 0.0111 - val_loss: 0.0121 - val_root_mean_squared_error: 0.0290
# Epoch 61/150
# 14/14 - 0s - loss: 0.0068 - root_mean_squared_error: 0.0117 - val_loss: 0.0123 - val_root_mean_squared_error: 0.0293
# Epoch 62/150
# 14/14 - 0s - loss: 0.0062 - root_mean_squared_error: 0.0114 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0289
# Epoch 63/150
# 14/14 - 0s - loss: 0.0058 - root_mean_squared_error: 0.0100 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0287
# Epoch 64/150
# 14/14 - 0s - loss: 0.0060 - root_mean_squared_error: 0.0105 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0285
# Epoch 65/150
# 14/14 - 0s - loss: 0.0064 - root_mean_squared_error: 0.0104 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0285
# Epoch 66/150
# 14/14 - 0s - loss: 0.0063 - root_mean_squared_error: 0.0102 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0289
# Epoch 67/150
# 14/14 - 0s - loss: 0.0065 - root_mean_squared_error: 0.0119 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0291
# Epoch 68/150
# 14/14 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0096 - val_loss: 0.0122 - val_root_mean_squared_error: 0.0294
# Epoch 69/150
# 14/14 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0107 - val_loss: 0.0108 - val_root_mean_squared_error: 0.0287
# Epoch 70/150
# 14/14 - 0s - loss: 0.0057 - root_mean_squared_error: 0.0090 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0285
# Epoch 71/150
# 14/14 - 0s - loss: 0.0070 - root_mean_squared_error: 0.0109 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0287
# Epoch 72/150
# 14/14 - 0s - loss: 0.0066 - root_mean_squared_error: 0.0111 - val_loss: 0.0124 - val_root_mean_squared_error: 0.0295
# Epoch 73/150
# 14/14 - 0s - loss: 0.0068 - root_mean_squared_error: 0.0111 - val_loss: 0.0131 - val_root_mean_squared_error: 0.0299
# Epoch 74/150
# 14/14 - 0s - loss: 0.0060 - root_mean_squared_error: 0.0103 - val_loss: 0.0126 - val_root_mean_squared_error: 0.0295
# Epoch 75/150
# 14/14 - 0s - loss: 0.0051 - root_mean_squared_error: 0.0094 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0284
# Epoch 76/150
# 14/14 - 0s - loss: 0.0073 - root_mean_squared_error: 0.0102 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0288
# Epoch 77/150
# 14/14 - 0s - loss: 0.0068 - root_mean_squared_error: 0.0113 - val_loss: 0.0123 - val_root_mean_squared_error: 0.0294
# Epoch 78/150
# 14/14 - 0s - loss: 0.0062 - root_mean_squared_error: 0.0102 - val_loss: 0.0130 - val_root_mean_squared_error: 0.0300
# Epoch 79/150
# 14/14 - 0s - loss: 0.0061 - root_mean_squared_error: 0.0106 - val_loss: 0.0130 - val_root_mean_squared_error: 0.0302
# Epoch 80/150
# 14/14 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0111 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0293
# Epoch 81/150
# 14/14 - 0s - loss: 0.0055 - root_mean_squared_error: 0.0100 - val_loss: 0.0109 - val_root_mean_squared_error: 0.0288
# Epoch 82/150
# 14/14 - 0s - loss: 0.0060 - root_mean_squared_error: 0.0102 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0287
# Epoch 83/150
# 14/14 - 0s - loss: 0.0068 - root_mean_squared_error: 0.0107 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0291
# Epoch 84/150
# 14/14 - 0s - loss: 0.0061 - root_mean_squared_error: 0.0105 - val_loss: 0.0120 - val_root_mean_squared_error: 0.0299
# Epoch 85/150
# 14/14 - 0s - loss: 0.0061 - root_mean_squared_error: 0.0105 - val_loss: 0.0128 - val_root_mean_squared_error: 0.0304
# Epoch 86/150
# 14/14 - 0s - loss: 0.0057 - root_mean_squared_error: 0.0104 - val_loss: 0.0128 - val_root_mean_squared_error: 0.0302
# Epoch 87/150
# 14/14 - 0s - loss: 0.0050 - root_mean_squared_error: 0.0096 - val_loss: 0.0108 - val_root_mean_squared_error: 0.0293
# Epoch 88/150
# 14/14 - 0s - loss: 0.0059 - root_mean_squared_error: 0.0102 - val_loss: 0.0108 - val_root_mean_squared_error: 0.0291
# Epoch 89/150
# 14/14 - 0s - loss: 0.0066 - root_mean_squared_error: 0.0113 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0292
# Epoch 90/150
# 14/14 - 0s - loss: 0.0062 - root_mean_squared_error: 0.0107 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0298
# Epoch 91/150
# 14/14 - 0s - loss: 0.0059 - root_mean_squared_error: 0.0103 - val_loss: 0.0124 - val_root_mean_squared_error: 0.0303
# Epoch 92/150
# 14/14 - 0s - loss: 0.0058 - root_mean_squared_error: 0.0097 - val_loss: 0.0129 - val_root_mean_squared_error: 0.0305
# Epoch 93/150
# 14/14 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0101 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0300
# Epoch 94/150
# 14/14 - 0s - loss: 0.0055 - root_mean_squared_error: 0.0102 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0297
# Epoch 95/150
# 14/14 - 0s - loss: 0.0057 - root_mean_squared_error: 0.0102 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0291
# Epoch 96/150
# 14/14 - 0s - loss: 0.0067 - root_mean_squared_error: 0.0114 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0295
# Epoch 97/150
# 14/14 - 0s - loss: 0.0060 - root_mean_squared_error: 0.0104 - val_loss: 0.0122 - val_root_mean_squared_error: 0.0303
# Epoch 98/150
# 14/14 - 0s - loss: 0.0061 - root_mean_squared_error: 0.0110 - val_loss: 0.0128 - val_root_mean_squared_error: 0.0304
# Epoch 99/150
# 14/14 - 0s - loss: 0.0051 - root_mean_squared_error: 0.0094 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0301
# Epoch 100/150
# 14/14 - 0s - loss: 0.0054 - root_mean_squared_error: 0.0107 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0298
# Epoch 101/150
# 14/14 - 0s - loss: 0.0053 - root_mean_squared_error: 0.0098 - val_loss: 0.0109 - val_root_mean_squared_error: 0.0295
# Epoch 102/150
# 14/14 - 0s - loss: 0.0064 - root_mean_squared_error: 0.0113 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0296
# Epoch 103/150
# 14/14 - 0s - loss: 0.0057 - root_mean_squared_error: 0.0102 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0299
# Epoch 104/150
# 14/14 - 0s - loss: 0.0060 - root_mean_squared_error: 0.0110 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0304
# Epoch 105/150
# 14/14 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0110 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0302
# Epoch 106/150
# 14/14 - 0s - loss: 0.0051 - root_mean_squared_error: 0.0095 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0299
# Epoch 107/150
# 14/14 - 0s - loss: 0.0054 - root_mean_squared_error: 0.0104 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0298
# Epoch 108/150
# 14/14 - 0s - loss: 0.0054 - root_mean_squared_error: 0.0090 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0296
# Epoch 109/150
# 14/14 - 0s - loss: 0.0065 - root_mean_squared_error: 0.0115 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0299
# Epoch 110/150
# 14/14 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0107 - val_loss: 0.0122 - val_root_mean_squared_error: 0.0304
# Epoch 111/150
# 14/14 - 0s - loss: 0.0061 - root_mean_squared_error: 0.0118 - val_loss: 0.0127 - val_root_mean_squared_error: 0.0307
# Epoch 112/150
# 14/14 - 0s - loss: 0.0053 - root_mean_squared_error: 0.0099 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0303
# Epoch 113/150
# 14/14 - 0s - loss: 0.0051 - root_mean_squared_error: 0.0096 - val_loss: 0.0109 - val_root_mean_squared_error: 0.0301
# Epoch 114/150
# 14/14 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0100 - val_loss: 0.0108 - val_root_mean_squared_error: 0.0298
# Epoch 115/150
# 14/14 - 0s - loss: 0.0065 - root_mean_squared_error: 0.0104 - val_loss: 0.0123 - val_root_mean_squared_error: 0.0305
# Epoch 116/150
# 14/14 - 0s - loss: 0.0059 - root_mean_squared_error: 0.0107 - val_loss: 0.0136 - val_root_mean_squared_error: 0.0313
# Epoch 117/150
# 14/14 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0100 - val_loss: 0.0126 - val_root_mean_squared_error: 0.0310
# Epoch 118/150
# 14/14 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0108 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0306
# Epoch 119/150
# 14/14 - 0s - loss: 0.0050 - root_mean_squared_error: 0.0100 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0301
# Epoch 120/150
# 14/14 - 0s - loss: 0.0062 - root_mean_squared_error: 0.0109 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0302
# Epoch 121/150
# 14/14 - 0s - loss: 0.0059 - root_mean_squared_error: 0.0103 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0306
# Epoch 122/150
# 14/14 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0101 - val_loss: 0.0121 - val_root_mean_squared_error: 0.0310
# Epoch 123/150
# 14/14 - 0s - loss: 0.0058 - root_mean_squared_error: 0.0112 - val_loss: 0.0120 - val_root_mean_squared_error: 0.0310
# Epoch 124/150
# 14/14 - 0s - loss: 0.0051 - root_mean_squared_error: 0.0098 - val_loss: 0.0114 - val_root_mean_squared_error: 0.0310
# Epoch 125/150
# 14/14 - 0s - loss: 0.0053 - root_mean_squared_error: 0.0105 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0308
# Epoch 126/150
# 14/14 - 0s - loss: 0.0055 - root_mean_squared_error: 0.0103 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0303
# Epoch 127/150
# 14/14 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0098 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0305
# Epoch 128/150
# 14/14 - 0s - loss: 0.0059 - root_mean_squared_error: 0.0115 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0313
# Epoch 129/150
# 14/14 - 0s - loss: 0.0053 - root_mean_squared_error: 0.0103 - val_loss: 0.0122 - val_root_mean_squared_error: 0.0313
# Epoch 130/150
# 14/14 - 0s - loss: 0.0050 - root_mean_squared_error: 0.0096 - val_loss: 0.0125 - val_root_mean_squared_error: 0.0313
# Epoch 131/150
# 14/14 - 0s - loss: 0.0047 - root_mean_squared_error: 0.0090 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0309
# Epoch 132/150
# 14/14 - 0s - loss: 0.0052 - root_mean_squared_error: 0.0096 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0304
# Epoch 133/150
# 14/14 - 0s - loss: 0.0066 - root_mean_squared_error: 0.0110 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0307
# Epoch 134/150
# 14/14 - 0s - loss: 0.0055 - root_mean_squared_error: 0.0100 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0311
# Epoch 135/150
# 14/14 - 0s - loss: 0.0054 - root_mean_squared_error: 0.0100 - val_loss: 0.0121 - val_root_mean_squared_error: 0.0311
# Epoch 136/150
# 14/14 - 0s - loss: 0.0056 - root_mean_squared_error: 0.0115 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0309
# Epoch 137/150
# 14/14 - 0s - loss: 0.0049 - root_mean_squared_error: 0.0093 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0309
# Epoch 138/150
# 14/14 - 0s - loss: 0.0057 - root_mean_squared_error: 0.0105 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0308
# Epoch 139/150
# 14/14 - 0s - loss: 0.0055 - root_mean_squared_error: 0.0098 - val_loss: 0.0114 - val_root_mean_squared_error: 0.0309
# Epoch 140/150
# 14/14 - 0s - loss: 0.0055 - root_mean_squared_error: 0.0106 - val_loss: 0.0120 - val_root_mean_squared_error: 0.0311
# Epoch 141/150
# 14/14 - 0s - loss: 0.0049 - root_mean_squared_error: 0.0095 - val_loss: 0.0114 - val_root_mean_squared_error: 0.0310
# Epoch 142/150
# 14/14 - 0s - loss: 0.0054 - root_mean_squared_error: 0.0103 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0314
# Epoch 143/150
# 14/14 - 0s - loss: 0.0057 - root_mean_squared_error: 0.0109 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0312
# Epoch 144/150
# 14/14 - 0s - loss: 0.0054 - root_mean_squared_error: 0.0097 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0310
# Epoch 145/150
# 14/14 - 0s - loss: 0.0055 - root_mean_squared_error: 0.0103 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0311
# Epoch 146/150
# 14/14 - 0s - loss: 0.0051 - root_mean_squared_error: 0.0097 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0315
# Epoch 147/150
# 14/14 - 0s - loss: 0.0055 - root_mean_squared_error: 0.0108 - val_loss: 0.0120 - val_root_mean_squared_error: 0.0320
# Epoch 148/150
# 14/14 - 0s - loss: 0.0055 - root_mean_squared_error: 0.0109 - val_loss: 0.0124 - val_root_mean_squared_error: 0.0315
# Epoch 149/150
# 14/14 - 0s - loss: 0.0050 - root_mean_squared_error: 0.0100 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0312
# Epoch 150/150
# 14/14 - 0s - loss: 0.0053 - root_mean_squared_error: 0.0101 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0312

# %% [markdown]
# ## Analysis

# %%
# make a prediction
yhat = model.predict(predict_X)
predict_X_2D = predict_X.reshape((predict_X.shape[0], predict_X.shape[2]))
# invert scaling for forecast
inv_yhat = np.concatenate((yhat, predict_X_2D[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
predict_y = predict_y.reshape((len(predict_y), 1))
inv_y = np.concatenate((predict_y, predict_X_2D[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
from sklearn.metrics import mean_squared_error

# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
normalized_rmse = rmse/(max(max(inv_yhat),max(inv_y))-min(min(inv_yhat),min(inv_y)))
print('Normalized RMSE: %.3f' % normalized_rmse)
# Out:
# Test RMSE: 0.002
# Normalized RMSE: 0.099

# %%
# Plot of Prediction vs Actual
pyplot.figure(figsize=(10,10))
pyplot.subplot(2, 1, 1)
pyplot.plot(inv_y, label="Actual")
pyplot.title("Actual")
pyplot.subplot(2, 1, 2)
pyplot.plot(inv_yhat, label="Prediction")
pyplot.title("Prediction")
pyplot.tight_layout()
pyplot.show()

# %%
import shap

# Create explainer for SHAP feature analysis
explainer = shap.GradientExplainer(model, train_X)
shap_values = explainer.shap_values(predict_X)
shap.initjs()

# Data has to be converted to 2D
shap_values_2D = shap_values[0].reshape(-1,13)
# Out:
# `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
# Plot of Feature Importance
shap.summary_plot(shap_values_2D, features=predict_X_2D, feature_names=df.columns)
